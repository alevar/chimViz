# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
breakpoints = pd.read_csv("../example/interactions.tsv",sep="\t",names=["seqid1","seqid2","pos1","pos2","count","junction1","junction2","gene1","gene2"])
breakpoints.head()
# Out:
#   seqid1    seqid2      pos1   pos2  count junction1           junction2  \
# 0      7  M33262.1  18888431   1240     23       vif  ENSMMUG00000001534
# 1      7  M33262.1  18888431   1240     29       vif  ENSMMUG00000001534
# 2     20  M33262.1  43612782  10533     38         -                   -
# 3     20  M33262.1  43612782   1072     29         -                   -
# 4     20  M33262.1  43612782  10533      8         -                   -
#
#                 gene1                                gene2
# 0  ENSMMUG00000001534  env;env/vpu;gag;nef;rev;tat;vif;vpr
# 1  ENSMMUG00000001534  env;env/vpu;gag;nef;rev;tat;vif;vpr
# 2                   -  env;env/vpu;gag;nef;rev;tat;vif;vpr
# 3                   -  env;env/vpu;gag;nef;rev;tat;vif;vpr
# 4                   -          env;gag;nef;rev;tat;vif;vpr

# %%
def custom_grouping(row):
    if row['gene1'] != '-':
        return (row['gene1'], row['seqid1'])
    else:
        return ((row['pos1'] - 1) // 100000, row['seqid1'])


genes = breakpoints[["seqid1","pos1","gene1"]]

# Apply the custom grouping function
genes['group'] = genes.apply(custom_grouping, axis=1)

# Group by the 'group' column
genes = genes.groupby('group').agg({'pos1': 'min', 'gene1': 'first', 'seqid1': 'first'}).reset_index(drop=True)
genes.to_csv()
# Out:
# /var/folders/kg/dntg2ryj6bb7y29gqk4q0r_c0000gn/T/ipykernel_2162/876509604.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genes['group'] = genes.apply(custom_grouping, axis=1)
#           pos1               gene1          seqid1
# 0        23026                   -  QNVO02001697.1
# 1      1213306                   -              19
# 2      2085411                   -              11
# 3      2171929                   -              20
# 4      2686562                   -               3
# ..         ...                 ...             ...
# 224   49067702  ENSMMUG00000055688               X
# 225   97533730  ENSMMUG00000057154               X
# 226   83281065  ENSMMUG00000057432              12
# 227   21220677  ENSMMUG00000060797               7
# 228  144005694  ENSMMUG00000061288               4
#
# [229 rows x 3 columns]
